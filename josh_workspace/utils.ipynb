# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Getting info on ip addresses

# %%
ip = '97.105.19.61'
# def ipinfo(ip):
import requests
host = 'https://ipinfo.io/'

response = requests.get(host+ip)

# %%
response.json()
# Out:
# {'ip': '97.105.19.61',
#  'hostname': '097-105-019-061.biz.spectrum.com',
#  'city': 'Houston',
#  'region': 'Texas',
#  'country': 'US',
#  'loc': '29.7633,-95.3633',
#  'org': 'AS11427 Charter Communications Inc',
#  'postal': '77002',
#  'timezone': 'America/Chicago',
#  'readme': 'https://ipinfo.io/missingauth'}

# %% [markdown]
# I ran into api limits on the ip geolocation services below.
# 'https://ipinfo.io/'
# 'https://geolocation-db.com/json/'
#
# I was able to find the service 'http://www.geoplugin.net' and found that it is free for up to 120 requests per minute.

# %%
def get_ip_info(ip=''):
    """For a single IP Address, get a dictionary describing the IP Address."""
    import requests
    host = 'http://www.geoplugin.net/json.gp?ip='
    response = requests.get(host+ip)
    return response.json()

# %%
get_ip_info(ip)
# Out:
# {'geoplugin_request': '97.105.19.61',
#  'geoplugin_status': 200,
#  'geoplugin_delay': '1ms',
#  'geoplugin_credit': "Some of the returned data includes GeoLite data created by MaxMind, available from <a href='http://www.maxmind.com'>http://www.maxmind.com</a>.",
#  'geoplugin_city': 'Euless',
#  'geoplugin_region': 'Texas',
#  'geoplugin_regionCode': 'TX',
#  'geoplugin_regionName': 'Texas',
#  'geoplugin_areaCode': '',
#  'geoplugin_dmaCode': '623',
#  'geoplugin_countryCode': 'US',
#  'geoplugin_countryName': 'United States',
#  'geoplugin_inEU': 0,
#  'geoplugin_euVATrate': False,
#  'geoplugin_continentCode': 'NA',
#  'geoplugin_continentName': 'North America',
#  'geoplugin_latitude': '32.8548',
#  'geoplugin_longitude': '-97.0819',
#  'geoplugin_locationAccuracyRadius': '20',
#  'geoplugin_timezone': 'America/Chicago',
#  'geoplugin_currencyCode': 'USD',
#  'geoplugin_currencySymbol': '$',
#  'geoplugin_currencySymbol_UTF8': '$',
#  'geoplugin_currencyConverter': 0}

# %% [markdown]
# This works.. but it's a bit cluttered imo.  Though it's easier to clean it up after it gets into dataframe format rather than at the requests level.

# %%
def build_ip_info_df(addresses):
    import time
    out = {}
    for i, ip in enumerate(addresses):
        time.sleep(.52)
        out[i] = get_ip_info(ip)
    return pd.DataFrame.from_dict(out, orient='index')

# %%
# I need the list of ips
import acquire
df = acquire.wrangle_data()

# %%
all_ips = df.ip.sort_values().unique().tolist()

# %%
len(all_ips)
# Out:
# 5200

# %%
pd.DataFrame(all_ips, columns=['ip'])
# Out:
#                   ip
# 0     100.11.170.135
# 1       100.19.73.35
# 2      100.35.67.162
# 3     103.137.12.164
# 4       104.1.46.153
# ...              ...
# 5195    99.97.210.12
# 5196   99.98.245.245
# 5197    99.98.32.165
# 5198     99.98.32.97
# 5199    99.98.36.168
#
# [5200 rows x 1 columns]

# %%
build_ip_info_df(all_ips[:5])
# Out:
#   geoplugin_request  geoplugin_status geoplugin_delay  \
# 0    100.11.170.135               200             2ms
# 1      100.19.73.35               200             2ms
# 2     100.35.67.162               200             1ms
# 3    103.137.12.164               200             1ms
# 4      104.1.46.153               200             2ms
#
#                                     geoplugin_credit geoplugin_city  \
# 0  Some of the returned data includes GeoLite dat...   Philadelphia
# 1  Some of the returned data includes GeoLite dat...   Philadelphia
# 2  Some of the returned data includes GeoLite dat...    Jersey City
# 3  Some of the returned data includes GeoLite dat...       Brisbane
# 4  Some of the returned data includes GeoLite dat...    San Antonio
#
#   geoplugin_region geoplugin_regionCode geoplugin_regionName  \
# 0     Pennsylvania                   PA         Pennsylvania
# 1     Pennsylvania                   PA         Pennsylvania
# 2       New Jersey                   NJ           New Jersey
# 3       Queensland                  QLD           Queensland
# 4            Texas                   TX                Texas
#
#   geoplugin_areaCode geoplugin_dmaCode  ... geoplugin_continentCode  \
# 0                                  504  ...                      NA
# 1                                  504  ...                      NA
# 2                                  501  ...                      NA
# 3                                       ...                      OC
# 4                                  641  ...                      NA
#
#   geoplugin_continentName  geoplugin_latitude  geoplugin_longitude  \
# 0           North America             40.0558             -75.0773
# 1           North America             40.0558             -75.0773
# 2           North America             40.7182             -74.0476
# 3                 Oceania            -27.4732             153.0215
# 4           North America             29.4873             -98.4532
#
#   geoplugin_locationAccuracyRadius  geoplugin_timezone geoplugin_currencyCode  \
# 0                                1    America/New_York                    USD
# 1                                1    America/New_York                    USD
# 2                                1    America/New_York                    USD
# 3                             1000  Australia/Brisbane                    AUD
# 4                               10     America/Chicago                    USD
#
#   geoplugin_currencySymbol geoplugin_currencySymbol_UTF8  \
# 0                        $                             $
# 1                        $                             $
# 2                        $                             $
# 3                        $                             $
# 4                        $                             $
#
#   geoplugin_currencyConverter
# 0                      0.0000
# 1                      0.0000
# 2                      0.0000
# 3                      1.4533
# 4                      0.0000
#
# [5 rows x 24 columns]

# %%
def get_ip_info(ip=''):
    """For a single IP Address, get a dictionary describing the IP Address."""
    import requests
    host = 'http://www.geoplugin.net/json.gp?ip='
    response = requests.get(host+ip)
    return response.json()

def build_ip_info_df(addresses):
    import time
    out = {}
    for i, ip in enumerate(addresses):
        time.sleep(.52)
        out[i] = get_ip_info(ip)
    return pd.DataFrame.from_dict(out, orient='index')

def get_ips():
    """WARNING: This will take over an hour if not reading from cache.
    
    Builds the unleaned IP geolocation dataframe."""
    import os
    filename='ips.csv'
    
    if os.path.isfile(filename):
        ips = pd.read_csv(filename)

    else:
        ip_list = acquire.wrangle_data().ip.sort_values().unique().tolist()
        ips = build_ip_info_df(ip_list)
        ips.to_csv(filename, index=False)
    return ips
    
def wrangle_ips():

    ips = get_ips()

    ips.columns = [col[10:] for col in ips]
    cols_to_keep = ['request',
                'status',
                'delay',
                'city',
                'regionCode',
                'regionName',
                'countryCode',
                'countryName',
                'continentName',
                'latitude',
                'longitude',
                ]
    ips = ips[cols_to_keep]
    ips = ips.rename(columns={'request':'ip'})

    return ips

# %%
pd.options.display.max_columns = None
ips = wrangle_ips()
ips.head()
# Out:
#                ip  status delay          city regionCode    regionName  \
# 0  100.11.170.135     200   1ms  Philadelphia         PA  Pennsylvania
# 1    100.19.73.35     200   1ms  Philadelphia         PA  Pennsylvania
# 2   100.35.67.162     200   1ms   Jersey City         NJ    New Jersey
# 3  103.137.12.164     200   1ms      Brisbane        QLD    Queensland
# 4    104.1.46.153     200   1ms   San Antonio         TX         Texas
#
#   countryCode    countryName  continentName  latitude  longitude
# 0          US  United States  North America   40.0558   -75.0773
# 1          US  United States  North America   40.0558   -75.0773
# 2          US  United States  North America   40.7182   -74.0476
# 3          AU      Australia        Oceania  -27.4732   153.0215
# 4          US  United States  North America   29.4873   -98.4532

# %%
ips.isna().sum()
# Out:
# ip                 0
# status             0
# delay              0
# city             878
# regionCode       687
# regionName       687
# countryCode        2
# countryName        2
# continentName      2
# latitude           2
# longitude          2
# dtype: int64

# %%
ips.status.value_counts()
# Out:
# 200    4322
# 206     876
# 404       2
# Name: status, dtype: int64

# %%
ips[ips.status == 404]
# Out:
#                  ip  status delay city regionCode regionName countryCode  \
# 860       127.0.0.1     404   1ms  NaN        NaN        NaN         NaN
# 4580  77.111.247.10     404   1ms  NaN        NaN        NaN         NaN
#
#      countryName continentName  latitude  longitude
# 860          NaN           NaN       NaN        NaN
# 4580         NaN           NaN       NaN        NaN

# %%
ips.countryName.value_counts()
# Out:
# United States          5079
# Mexico                   35
# Canada                   18
# Bahamas                  17
# France                   11
# Thailand                 11
# Germany                   7
# Turkey                    6
# Australia                 3
# Ukraine                   2
# India                     1
# Puerto Rico               1
# U.S. Virgin Islands       1
# Singapore                 1
# China                     1
# Switzerland               1
# United Kingdom            1
# Sweden                    1
# Ireland                   1
# Name: countryName, dtype: int64

# %%
df = df.merge(ips, how='left', on='ip', suffixes=[None,'_ip'])

# %%
df.isna().sum()
# Out:
# ip                    0
# endpoint              0
# user_id               0
# cohort_id             0
# cohort_name           0
# slack                 0
# start_date            0
# end_date              0
# program_id            0
# program               0
# module            45854
# lesson           191445
# status                0
# delay                 0
# city              10860
# regionCode         9283
# regionName         9283
# countryCode           8
# countryName           8
# continentName         8
# latitude              8
# longitude             8
# dtype: int64

# %%
df.countryName.value_counts(dropna=False)
# Out:
# United States          845723
# Mexico                    446
# Turkey                    319
# Canada                    244
# Germany                   193
# Bahamas                   129
# France                     88
# Thailand                   59
# Switzerland                48
# Australia                  23
# Ireland                    18
# India                       9
# NaN                         8
# Sweden                      5
# U.S. Virgin Islands         4
# Ukraine                     4
# Singapore                   4
# United Kingdom              2
# China                       2
# Puerto Rico                 1
# Name: countryName, dtype: int64

# %%
def merge_ip_info(df):
    ips = wrangle_ips()
    df = df.merge(ips, how='left', on='ip', suffixes=[None,'_ip'])
    return df

# %%
df = acquire.wrangle_data()
df = merge_ip_info(df)
df.head()
# Out:
#              ip                             endpoint  user_id  cohort_id  \
# 0  97.105.19.61                                    /        1        8.0
# 1  97.105.19.61                              java-ii        1        8.0
# 2  97.105.19.61  java-ii/object-oriented-programming        1        8.0
# 3  97.105.19.61   slides/object_oriented_programming        1        8.0
# 4  97.105.19.61            javascript-i/conditionals        2       22.0
#
#   cohort_name     slack           start_date             end_date  program_id  \
# 0     Hampton  #hampton  2015-09-22 00:00:00  2016-02-06 00:00:00           1
# 1     Hampton  #hampton  2015-09-22 00:00:00  2016-02-06 00:00:00           1
# 2     Hampton  #hampton  2015-09-22 00:00:00  2016-02-06 00:00:00           1
# 3     Hampton  #hampton  2015-09-22 00:00:00  2016-02-06 00:00:00           1
# 4       Teddy    #teddy  2018-01-08 00:00:00  2018-05-17 00:00:00           2
#
#            program        module                       lesson  status delay  \
# 0   Full Stack PHP          None                         None     200   1ms
# 1   Full Stack PHP       java-ii                         None     200   1ms
# 2   Full Stack PHP       java-ii  object-oriented-programming     200   1ms
# 3   Full Stack PHP        slides  object_oriented_programming     200   1ms
# 4  Full Stack Java  javascript-i                 conditionals     200   1ms
#
#      city regionCode regionName countryCode    countryName  continentName  \
# 0  Euless         TX      Texas          US  United States  North America
# 1  Euless         TX      Texas          US  United States  North America
# 2  Euless         TX      Texas          US  United States  North America
# 3  Euless         TX      Texas          US  United States  North America
# 4  Euless         TX      Texas          US  United States  North America
#
#    latitude  longitude
# 0   32.8548   -97.0819
# 1   32.8548   -97.0819
# 2   32.8548   -97.0819
# 3   32.8548   -97.0819
# 4   32.8548   -97.0819

# %%
def wrangle_ip_merged():
    df = acquire.wrangle_data()
    df = df.reset_index()
    df = merge_ip_info(df)
    df = df.set_index('datetime')
    return df

# %%
df = wrangle_ip_merged()
df.head()
# Out:
#                                ip                             endpoint  \
# datetime
# 2018-01-26 09:55:03  97.105.19.61                                    /
# 2018-01-26 09:56:02  97.105.19.61                              java-ii
# 2018-01-26 09:56:05  97.105.19.61  java-ii/object-oriented-programming
# 2018-01-26 09:56:06  97.105.19.61   slides/object_oriented_programming
# 2018-01-26 09:56:24  97.105.19.61            javascript-i/conditionals
#
#                      user_id  cohort_id cohort_name     slack  \
# datetime
# 2018-01-26 09:55:03        1        8.0     Hampton  #hampton
# 2018-01-26 09:56:02        1        8.0     Hampton  #hampton
# 2018-01-26 09:56:05        1        8.0     Hampton  #hampton
# 2018-01-26 09:56:06        1        8.0     Hampton  #hampton
# 2018-01-26 09:56:24        2       22.0       Teddy    #teddy
#
#                               start_date             end_date  program_id  \
# datetime
# 2018-01-26 09:55:03  2015-09-22 00:00:00  2016-02-06 00:00:00           1
# 2018-01-26 09:56:02  2015-09-22 00:00:00  2016-02-06 00:00:00           1
# 2018-01-26 09:56:05  2015-09-22 00:00:00  2016-02-06 00:00:00           1
# 2018-01-26 09:56:06  2015-09-22 00:00:00  2016-02-06 00:00:00           1
# 2018-01-26 09:56:24  2018-01-08 00:00:00  2018-05-17 00:00:00           2
#
#                              program        module  \
# datetime
# 2018-01-26 09:55:03   Full Stack PHP          None
# 2018-01-26 09:56:02   Full Stack PHP       java-ii
# 2018-01-26 09:56:05   Full Stack PHP       java-ii
# 2018-01-26 09:56:06   Full Stack PHP        slides
# 2018-01-26 09:56:24  Full Stack Java  javascript-i
#
#                                           lesson  status delay    city  \
# datetime
# 2018-01-26 09:55:03                         None     200   1ms  Euless
# 2018-01-26 09:56:02                         None     200   1ms  Euless
# 2018-01-26 09:56:05  object-oriented-programming     200   1ms  Euless
# 2018-01-26 09:56:06  object_oriented_programming     200   1ms  Euless
# 2018-01-26 09:56:24                 conditionals     200   1ms  Euless
#
#                     regionCode regionName countryCode    countryName  \
# datetime
# 2018-01-26 09:55:03         TX      Texas          US  United States
# 2018-01-26 09:56:02         TX      Texas          US  United States
# 2018-01-26 09:56:05         TX      Texas          US  United States
# 2018-01-26 09:56:06         TX      Texas          US  United States
# 2018-01-26 09:56:24         TX      Texas          US  United States
#
#                      continentName  latitude  longitude
# datetime
# 2018-01-26 09:55:03  North America   32.8548   -97.0819
# 2018-01-26 09:56:02  North America   32.8548   -97.0819
# 2018-01-26 09:56:05  North America   32.8548   -97.0819
# 2018-01-26 09:56:06  North America   32.8548   -97.0819
# 2018-01-26 09:56:24  North America   32.8548   -97.0819
